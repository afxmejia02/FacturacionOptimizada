# %%
import pdfplumber

path = r"C:\Users\andres.mejia\OneDrive - Consorcio Tabarca\Documentos\proceso-facturacion\13. INFORME DE EQUIPOS - PAGO 32 - Inteligencia Artificial.pdf"
with pdfplumber.open(path) as pdf:
    page = pdf.pages[0]
    table = page.extract_table()
    for row in table:        
        print(row)
# Out:
# ['', None, None, None, None, None, None, None, None, None, '']
# ['FORMATO DE REGISTRO DE ELEMENTOS, HERRAMIENTAS Y EQUIPOS TRANSVERSALES\nToken ID documental: COL-P0039-0105 Versión: 1 Vigente desde: 10/01/2025', None, None, None, None, None, None, None, None, None, None]
# ['', '1. INFORMACIÓN GENERAL', None, None, None, None, None, None, None, None, '']
# ['', 'EMPRESA:', None, 'Consorcio Tabarca', None, 'ORDEN DE SERVICIO No\n058', '“ALISTAMIENTO, EJECUCIÓN Y CIERRE PARA\nACTIVIDADES DE MANTENIMIENTO - MONTAJE DE\nEQUIPOS EN LA REFINERÍA DE BARRANCABERMEJA 2025-\n2026 (SEP 2025 - SEP 2026)”', None, 'EQUIPO:', 'CAMIÓN-GRÚA DE 10 TON (10 H)', '']
# [None, 'NIT:', None, '901290945-6', None, None, None, None, 'NOMBRE:', 'JAVIER CAMACHO SANCHEZ', None]
# [None, 'DIRECCIÓN:', None, 'Carrera 30a No. 76 - 15 La Florestica - Barrancabermeja\n(S)', None, None, None, None, 'CARGO:', 'COORDINADOR I', None]
# ...

# %%
import pdfplumber

path = r"C:\Users\andres.mejia\OneDrive - Consorcio Tabarca\Documentos\proceso-facturacion\FORMATO EQUIPOS.pdf"
with pdfplumber.open(path) as pdf:
    page = pdf.pages[0]
    table = page.extract_table()
    for row in table:        
        print(row)
# Out:
# ['', None, None, None, None, None, None, None, None, None, '']
# ['FORMATO PARA AUTORIZACION DE REGISTRO DE OBRAS O SERVICIOS TIPICOS\nToken ID documental: COL-P0039-0105 Versión: 1 Vigente desde: 10/01/2025', None, None, None, None, None, None, None, None, None, None]
# ['', '1. INFORMACIÓN GENERAL', None, None, None, None, None, None, None, None, '']
# ['', 'EMPRESA:', None, 'Consorcio Tabarca', None, 'ORDEN DE SERVICIO No 060', 'ALISTAMIENTO DE LA TEA 2 Y ALISTAMIENTO Y EJECUCION DE SERVICIOS\nESPECIALES DE CAMBIO DE CATALIZADOR, DECOQUIZADO Y SMART PIGGING DE\nLAS UNIDADES U4650 Y U4700 PARA LAS PARADAS GENERALES DEL\nDEPARTAMENTO DE CRUDOS Y DEL DEPARTAMENTO DE CRACKING II/III DE LA\nGERENCIA REFINERÍA BARRANCABERMEJA DE ECOPETROL S.A. AÑO 2026,\nUBICADA EN BARRANCABERMEJA, SANTANDER', None, 'EQUIPO:', 'Climatización - Confort térmico', '']
# [None, 'NIT:', None, '901290945-6', None, None, None, None, 'NOMBRE:', 'CARLOS BARON BARON', None]
# ...
