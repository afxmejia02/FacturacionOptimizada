# %%
import pdfplumber

path = r"C:\Users\andres.mejia\OneDrive - Consorcio Tabarca\Documentos\proceso-facturacion\Planilla de tiempos 14-04-2026 OSM060 CONSOLIDADA.pdf"
with pdfplumber.open(path) as pdf:
    for page in pdf.pages:
        tables = page.extract_tables()
        for tabla in tables:
            if len(tabla) > 5:
                print(f"Tabla[4]: {tabla[4][2]}")
# Out:
# Tabla encontrada: [['1.INFORMACIÓN GENERAL', None, None, None, None, None, None, None, None, None, None], ['EMPRESA:', None, 'CONSORCIO TABARCA BARRANCABERMEJA CONTRATO N° 3023604', None, None, None, None, None, 'NIT:', '901290945-6', None], ['DIRECCIÓN:', None, 'CARRERA 30 A NO. 76 – 15/23 BARRIO LA FLORESTICA', None, None, None, None, None, None, None, None], ['OBJETO DE LA ORDEN DE SERVICIO:', None, 'OSM060: ALISTAMIENTO DE LA TEA 2 Y ALISTAMIENTO Y EJECUCION DE SERVICIOS ESPECIALES DE CAMBIO DE CATALIZADOR, DECOQUIZADO Y SMART PIGGING DE LAS UNIDADES U4650 Y U4700 PARA LAS\nPARADAS GENERALES DEL DEPARTAMENTO DE CRUDOS Y DEL DEPARTAMENTO DE CRACKING II/III DE LA GERENCIA REFINERÍA BARRANCABERMEJA DE ECOPETROL S.A. AÑO 2026, UBICADA EN\nBARRANCABERMEJA, SANTANDER', None, None, None, None, None, None, None, None], ['RESPONSABLE GRUPO DE TRABAJO', None, 'CARLOS BARON-GLOBAL-ALISTAMIENTO-PRIMED-H2-JORNADA E', None, None, None, None, None, 'CARGO:', 'DIRECTOR DE ORDEN DE SERVICIO', Non
# ...

# %%
#organizar la tabla encontrada en un formato más legible
#Tabla encontrada: 
#Tabla encontrada: 
# [
# ['1.INFORMACIÓN GENERAL', None, None, None, None, None, None, None, None, None, None]
# , ['EMPRESA:', None, 'CONSORCIO TABARCA BARRANCABERMEJA CONTRATO N° 3023604', None, None, None, None, None, 'NIT:', '901290945-6', None]
# , ['DIRECCIÓN:', None, 'CARRERA 30 A NO. 76 – 15/23 BARRIO LA FLORESTICA', None, None, None, None, None, None, None, None]
# , ['OBJETO DE LA ORDEN DE SERVICIO:', None, 'OSM060: ALISTAMIENTO DE LA TEA 2 Y ALISTAMIENTO Y EJECUCION DE SERVICIOS ESPECIALES DE CAMBIO DE CATALIZADOR, DECOQUIZADO Y SMART PIGGING DE LAS UNIDADES U4650 Y U4700 PARA LAS\nPARADAS GENERALES DEL DEPARTAMENTO DE CRUDOS Y DEL DEPARTAMENTO DE CRACKING II/III DE LA GERENCIA REFINERÍA BARRANCABERMEJA DE ECOPETROL S.A. AÑO 2026, UBICADA EN\nBARRANCABERMEJA, SANTANDER', None, None, None, None, None, None, None, None]
# , ['RESPONSABLE GRUPO DE TRABAJO', None, 'CARLOS BARON-GLOBAL-ALISTAMIENTO-PRIMED-H2-JORNADA E', None, None, None, None, None, 'CARGO:', 'DIRECTOR DE ORDEN DE SERVICIO', None], ['TIPO ORDEN DE SERVICIO:', None, 'Alistamiento / Prefabricado', None, None, None, None, None, None, None, None], ['DATOS', None, None, 'Nivel/\nPerfil', 'C\nO\nD\nI', 'HORARIO', None, 'H\nO\nR', 'FECHA:', None, '14-04-2026'], ['CEDULA', 'TRABAJADOR', 'CARGO', '', 'G\nO', 'INGRESO', 'SALIDA', 'A\nS', 'CUADRILLA TIE', 'FIRMA DEL TRABAJADOR', 'OBSERVACIONES'], ['13570491', 'BAYRON MANUEL MADERA PLATA', 'CONDUCTOR VEHÍCULO LIVIANO', 'A2', 'M32', '07:30', '16:30', '9,0', '---', '', ''], ['91489291', 'CARLOS JULIO GOMEZ LEON', 'CONDUCTOR VEHÍCULO LIVIANO', 'A2', 'M32', '07:30', '16:30', '9,0', '---', '', ''], ['91443147', 'JAVIER MAURICIO CHACON GUARIN', 'CONDUCTOR VEHÍCULO DE MÁS DE\n3 TON', 'C6', 'M32', '07:30', '16:30', '9,0', '---', '', '']]
