# %%
path = "PLANILLA DE EQUPOS Y SERVICIOS 06 JUNIO PDF.pdf"
#convertir imagen a texto
import pdfplumber


with pdfplumber.open(path) as pdf:
    for page in pdf.pages:
        text = page.extract_text()
        print(text)
# Out:
# FRM-BCA-19.370.3.GA01
# FORMATO DE REGISTRO DE EQUIPOS Y SERVICIOS Fecha: 26/02/2021
# Versión: 2
# CONTRATO: 3023605 MANTENIMIENTO CON PARADA DE PLANTA Y EN OPERACIÓN DE LAS UNIDADES DE LA REFINERÍA DE BARRANCABERMEJA
# PLANTA O
# ORDEN DE SERVICIO: ODS-049 U2000 FECHA 06-Jun-26 TURNO E
# FRENTE
# CANTIDAD FIRMA SUPERVISOR FIRMA GESTIÓN TÉCNICA
# CONSE ITEM PAGO EQUIPO O SERVICIO UNIDAD OBSERVACIONES
# ITEM UT ITALCO ECP
# Camperos o camionetas 4x2 Grupo “A”, con
# 1 5.5.9.3 0,033 MES PLACA VEHICULO: NFU-554
# conductor (10 Horas)
# 2 5.5.1.105 Montacargas 3 Ton (10 H) 1 DÍA MARCA: HANGCHA / SN: F4AH29039
# 3 5.5.1.108 Camión-grúa de 10 Ton (10 H) 1 DÍA PLACA VEHICULO: WOM-637
# MARCA: ESAB SN: 635- MARCA: ESAB SN: MARCA: ESAB
# 4 5.5.5.1 Equipo de soldadura hasta 400 Amp (24 H). 3 DÍA
# 936-0426 635-017-0595 SN: 635-018-0602
# 5 5.5.5.5 Motosoldador hasta 400 Amp (24 H) 1 DÍA MARCA: MILLER /SN: MF040038E
# 6 5.5.5.9 Equipo para proceso TIG (24 H) 4 DÍA
# ...
