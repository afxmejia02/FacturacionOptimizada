# %%
import pdfplumber
path_pdf="docs/2.planillas Pago Seguridad Social/ssocial octubre 2025.pdf"
with pdfplumber.open(path_pdf) as pdf:
    conteo = 0
    for page in pdf.pages:
        text = page.extract_table()
        conteo += 1
        print(f"Página {conteo}:")
        print(text)
# Out:
# Página 1:
# ...
